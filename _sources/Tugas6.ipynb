# %% [markdown]
# # Decision Tree (Tugas 6)
# ## Gini Index
# Rumus :
#
# Gini =  $$ 1 - sigma_1 -_n (p_i)^2 $$

# %%
import pandas as pd
#membaca data iris
df = pd.read_csv('/content/drive/MyDrive/datamining/tugas/Iris.csv')
#menampilkan 5 data teratas
df.head()
